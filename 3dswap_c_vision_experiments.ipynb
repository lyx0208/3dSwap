# %% [markdown]
# Colab notebook for 3dSwap by Phillip T. Chananda, Credit to the developer Yixuan Li https://github.com/lyx0208

# %% [markdown]
# DATASET PREPROCESSING STEPS
#
# 1. First clone 3dSwap
# 2. Go to eg3d notebook clone the repo and place your dataset in the dataset path in eg3d and edit dataset_name
# 3. Then run the rest of the eg3d code.
# 4. Then return to 3dSwap and then edit the dataroot and finally run this notebook.

# %%
from google.colab import drive
drive.mount("/content/drive/")

# %%
# %cd "/content/drive/MyDrive/3dSwap/"
# !ls

# %%
# !git clone https://github.com/lyx0208/3dSwap.git
# %cd 3dSwap

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# %%
# !conda --version

# %%
# !conda create -n 3dSwap python=3.8

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.8/site-packages"))

# %%
# %%shell
# cd /content/drive/MyDrive/3dSwap
# source activate 3dSwap
# pip install -r requirements.txt

# %%
# %%shell
# source activate 3dSwap
# # pip install torch==2.0.1 torchvision==0.15.2 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118
# # pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 --extra-index-url https://download.pytorch.org/whl/cu111
# # pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0 --extra-index-url https://download.pytorch.org/whl/cu113
# pip install torch==2.2.0 torchvision==0.17.0 torchaudio==2.2.0 --index-url https://download.pytorch.org/whl/cu121

# %% [markdown]
# INSTALL MISSING PACKAGES

# %%
# uncomment run if these packages are not installed
# %%shell
source activate 3dSwap
pip install imgui
pip install Ninja numpy
pip install scikit-image
pip install plyfile
pip install trimesh
pip install ninja
pip install click
pip install mrcfile
pip install mediapipe
pip install opencv-python
pip install pillow
pip install ipykernel
# pip install dlib

# %% [markdown]
# INFERENCE CODE

# %%
# %%shell
# cd /content/drive/MyDrive/3dSwap
# source activate 3dSwap
# python run_3dSwap.py  --epoch 1000  --to_index "A" --from_index "B" --dataroot "/content/drive/MyDrive/3dSwap/datasets/test_images"

# %% [markdown]
# INFERENCE CODE FOR INVERSION

# %%
#!python run_inversion.py --from_index "apex-cropped-repression-36-64" --to_index "apex-cropped-others-16-69" --dataroot "datasets/my_dataset"

# %% [markdown]
# TRAINING CODE FOR FACESWAPPING

# %%
# %%shell
# cd /content/drive/MyDrive/3dSwap/
# source activate 3dSwap
# python -m torch.distributed.run --nproc_per_node=1 --master_port=12345  fine_tune.py --workers=2  --exp_dir=faceswap
